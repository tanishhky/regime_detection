# %%
# %run regime_system_modules.py
# Out:
# ...
# REGIME-BASED PORTFOLIO OPTIMIZATION SYSTEM
# ...
#
# 📊 Current Configuration:
#   • Short-term trend: 21 days
#   • Long-term trend: 63 days
#   • Number of regimes: 4
#   • Rebalancing period: 63 days
#   • Max position size: 15.0%
#   • Shrinkage (regularization): 60.0%
#
# ✓ All modules loaded successfully!
#
# Available components:
#   • DataGenerator - Synthetic market data
#   • RegimeDetector - HMM-based regime detection
#   • PortfolioOptimizer - Mean-variance optimization
#   • Backtester - Strategy backtesting (⚠️ HAS LOOK-AHEAD BIAS)
#   • WalkForwardBacktester - Proper walk-forward (✓ NO BIAS)
#   • BootstrapGenerator - Data bootstrapping methods
#   • PerformanceMetrics - Performance analysis
#   • Visualizer - Comprehensive visualizations
#
# 🚀 Ready to run tests!
#
# ⚠️  IMPORTANT: Use WalkForwardBacktester for realistic results!
#    The regular Backtester has look-ahead bias and inflates performance.

# %%
# %run regime_comprehensive_tests.py
# Out:
# ...
# REGIME-BASED PORTFOLIO OPTIMIZATION SYSTEM
# ...
#
# 📊 Current Configuration:
#   • Short-term trend: 21 days
#   • Long-term trend: 63 days
#   • Number of regimes: 4
#   • Rebalancing period: 63 days
#   • Max position size: 15.0%
#   • Shrinkage (regularization): 60.0%
#
# ✓ All modules loaded successfully!
#
# Available components:
#   • DataGenerator - Synthetic market data
#   • RegimeDetector - HMM-based regime detection
#   • PortfolioOptimizer - Mean-variance optimization
#   • Backtester - Strategy backtesting (⚠️ HAS LOOK-AHEAD BIAS)
#   • WalkForwardBacktester - Proper walk-forward (✓ NO BIAS)
#   • BootstrapGenerator - Data bootstrapping methods
#   • PerformanceMetrics - Performance analysis
#   • Visualizer - Comprehensive visualizations
#
# 🚀 Ready to run tests!
#
# ⚠️  IMPORTANT: Use WalkForwardBacktester for realistic results!
#    The regular Backtester has look-ahead bias and inflates performance.
# ...
# COMPREHENSIVE TEST SUITE V2.0 - NO LOOK-AHEAD BIAS
# ...
#
# ...
